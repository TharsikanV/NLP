# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in c:\users\tharsikan\appdata\roaming\python\python314\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in c:\users\tharsikan\appdata\roaming\python\python314\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\tharsikan\appdata\roaming\python\python314\site-packages (from nltk) (4.69.0)
# Requirement already satisfied: colorama in c:\users\tharsikan\appdata\roaming\python\python314\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

nltk.download('punkt_tab')

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tharsikan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tharsikan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tharsikan\AppData\Roaming\nltk_data...
# True

# %%
corpus="""Helllo Welcome,to krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Helllo Welcome,to krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
## Tokenization
## Paragraphs ---> Sentence
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Helllo Welcome,to krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
##Tokenization
##Paragraphs ---> words
##sentence  ---> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Helllo',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Helllo', 'Welcome', ',', 'to', 'krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Helllo',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)#last . is only consider separete
# Out:
# ['Helllo',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
