# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam

# %%
df=pd.read_csv('data.csv',parse_dates=['Date'],index_col='Date')
print(df.head())
# Out:
#             Temperature
# Date
# 2010-01-01    27.483571
# 2010-01-02    24.308678
# 2010-01-03    28.238443
# 2010-01-04    32.615149
# 2010-01-05    23.829233

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
print(scaled_data)
# Out:
# [[0.5496123 ]
#  [0.46622273]
#  [0.56943925]
#  ...
#  [0.37470644]
#  [0.70145198]
#  [0.757248  ]]

# %%
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)


time_step = 100
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(GRU(units=50))
model.add(Dense(units=1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100, 50)        │         7,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,301 (91.02 KB)
#  Trainable params: 23,301 (91.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0221
# Epoch 2/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0181
# Epoch 3/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0179
# Epoch 4/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0178
# Epoch 5/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0178
# Epoch 6/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0178
# Epoch 7/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0179
# Epoch 8/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0179
# Epoch 9/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0177
# Epoch 10/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0177

# %%
input_sequence = scaled_data[-time_step:].reshape(1, time_step, 1)
predicted_values = model.predict(input_sequence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step

# %%
predicted_values = scaler.inverse_transform(predicted_values)
print(
    f"The predicted temperature for the next day is: {predicted_values[0][0]:.2f}°C")
# Out:
# The predicted temperature for the next day is: 26.34°C
